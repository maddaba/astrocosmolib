# %%
#%load_ext autoreload
#%autoreload 2

import sys
sys.path.append("../")

# %%
from pyACC.fits_wrapper import FitsManager

# %%
input_file= "/home/maddaba/astrocosmolib/test/HorseHead.fits"

# %%
horse_head_fits=FitsManager(input_file)
# Out:
# 2025-03-18 12:41:50.348858 :: FitsManager :: INFO :: Fits open succesfully

# %%
horse_head_fits.input_file
# Out:
# '/home/maddaba/astrocosmolib/test/HorseHead.fits'

# %%
horse_head_fits.hdulist
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f7c34b7ef90>, <astropy.io.fits.hdu.table.TableHDU object at 0x7f7c34b95730>]

# %%
horse_head_fits.get_hdu_count()
# Out:
# 2

# %%
data = horse_head_fits.get_data(0) #devo fornire indice, glielo ho detto nel file fits_manager.py, se mettessi -1 ottengo come messaggio: FitsManager :: ERROR :: Invalid hdu index

# %%
import matplotlib.pyplot as plt
plt.imshow(data, cmap='gray')
plt.show()
